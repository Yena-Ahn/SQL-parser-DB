# %%
from bsddb3 import db

# %%
import os.path

# %%
myDB = db.DB()
myDB.open('myDB.db', dbtype=db.DB_HASH)
myDB.close()

# %%
def create_table(table_name, ):
  pass
def drop_table(table_name):
  pass
def desc_table(table_name):
  pass
def show_table(table_name):
  filename = get_filename
  tableDB = db.DB()
  tableDB.open(f"{filename}", dbtype=db.DB_HASH)
  cursor = tableDB.cursor()
  while x:= cursor.next():
    x #print(x)

def exists(table_name):
  filename = get_filename(table_name)
  path = f"/dbfiles/{filename}"
  if os.path.exists(path):
    db.remove(path)
  else:
    Error.NoSuchTable()
def get_filename(table_name):
  return f"{table_name}.db"

# %%
class Error():
  def NoSuchTable():
    pass
  def DropReferencedTableError(table_name):
    pass
